# %%
import cv2
import numpy as np
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt
import os

# %%
files = glob('C:\\Users\\kimso\\Desktop\\220112_test\\*.bmp')
files
# Out:
# ['C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_165707_1.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_165709_2.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_165907_4 _ 10.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_165920_5 _ 10.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_170112_6.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_170125_7.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_170128_8.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_170344_9.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\Pic_2022_01_12_170402_10.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\z축0_트레이15_NIR.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\z축0_트레이15_RGB.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\z축0_트레이30_NIR.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\z축0_트레이30_RGB.bmp',
#  'C:\\Users\\kimso\\Desktop\\220112_test\\z축150_트레이30_NIR.bmp',
# ...

# %%
#1번이미지
img = cv2.imread(files[0])

# img_resize = cv2.resize(img, dsize=(640,480))

h, w = img.shape[:2]
img_1 = img[0:int(h/3),:,:]

img_1.shape

img_1_1 = img_1[:,0:int(w/3),:]

img_1_1.shape

plt.imshow(img_1_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_1.png',img_1_1)
# Out:
# True

# %%
#2번이미지
img_2 = img[int(h/3):int(2*h/3),:,:]

img_2.shape

img_2_1 = img_2[:,0:int(w/3),:]

img_2_1.shape

plt.imshow(img_2_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_2.png',img_2_1)
# Out:
# True

# %%
#3번이미지
img_3 = img[int(2*h/3):int(h),:,:]

img_3.shape

img_3_1 = img_3[:,0:int(w/3),:]

img_3_1.shape

plt.imshow(img_3_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_3.png',img_3_1)
# Out:
# True

# %%
#4번이미지
img_4 = img[0:int(h/3),:,:]

img_4.shape

img_4_1 = img_4[:,int(w/3):int(2*w/3),:]

img_4_1.shape

plt.imshow(img_4_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_4.png',img_4_1)
# Out:
# True

# %%
#5번이미지
img_5 = img[int(h/3):int(2*h/3),:,:]

img_5.shape

img_5_1 = img_5[:,int(w/3):int(2*w/3),:]

img_5_1.shape

plt.imshow(img_5_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_5.png',img_5_1)
# Out:
# True

# %%
#6번이미지
img_6 = img[int(2*h/3):int(3*h/3),:,:]

img_6.shape

img_6_1 = img_6[:,int(w/3):int(2*w/3),:]

img_6_1.shape

plt.imshow(img_6_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_6.png',img_6_1)
# Out:
# True

# %%
#7번이미지
img_7 = img[:int(1*h/3),:,:]

img_7.shape

img_7_1 = img_7[:,int(2*w/3):int(3*w/3),:]

img_7_1.shape

plt.imshow(img_7_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_7.png',img_7_1)
# Out:
# True

# %%
#8번이미지
img_8 = img[int(1*h/3):int(2*h/3),:,:]

img_8.shape

img_8_1 = img_8[:,int(2*w/3):int(3*w/3),:]

img_8_1.shape

plt.imshow(img_8_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_8.png',img_8_1)
# Out:
# True

# %%
#9번이미지
img_9 = img[int(2*h/3):int(3*h/3),:,:]

img_9.shape

img_9_1 = img_9[:,int(2*w/3):int(3*w/3),:]

img_9_1.shape

plt.imshow(img_9_1)

cv2.imwrite('C:\\Users\\kimso\\Desktop\\get_germination_rate\\results\\result_9.png',img_9_1)
# Out:
# True
